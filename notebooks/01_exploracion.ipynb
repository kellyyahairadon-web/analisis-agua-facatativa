# %% [markdown]
# # 🌿 Reto 1 – Análisis de Calidad del Agua
#
# ## 🎯 Objetivo
# Analizar la relación entre variables ambientales como pH, oxígeno, temperatura y conductividad para evaluar la calidad del agua.
#
# ---
#
# ## 📥 Carga de datos
# En esta sección se importa el dataset y se realiza una primera inspección.
