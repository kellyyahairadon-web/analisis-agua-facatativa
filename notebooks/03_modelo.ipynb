# %% [markdown]
# # 🌿 Reto 3 – Funciones y generación de indicadores
#
# ## 🎯 Objetivo
# Aplicar funciones personalizadas para generar indicadores de calidad del agua y realizar análisis estadísticos avanzados.
#
# ---
#
# ## 📥 Carga de datos
# Se utiliza el dataset procesado previamente.
